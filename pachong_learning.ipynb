# %%
import requests

request_headers = {
    'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'Accept-encoding':'gzip, deflate, br',
    'Accept-language':'zh,en-US;q=0.9,en;q=0.8,zh-TW;q=0.7,zh-CN;q=0.6,zh-HK;q=0.5',
    'Cache-control':'max-age=0',
    'Cookie':'_zap=d756ec26-4319-4aa7-a907-44bef8b8cc4a; _xsrf=2f696c89-c093-47e6-acd0-5284eaa4e181; d_c0="AICjeSCNExCPTifRRV0t2OVtBKiXR9RnNDc=|1568969970"; z_c0="2|1:0|10:1569056218|4:z_c0|92:Mi4xUGJ2eEF3QUFBQUFBZ0tONUlJMFRFQ1lBQUFCZ0FsVk4yak56WGdDVkM2ZUFmNEVac0Y1MGdUc3lINlVhdTBJNnVn|8448475a508b016bc27adcd9b58ea946b641d0e5f6bc2b344b76d298e5f24c73"; q_c1=a690ead776234427b70f3ef6cb9cb5a3|1572073804000|1569056401000; tst=h; tshl=digital; tgw_l7_route=7bacb9af7224ed68945ce419f4dea76d; Hm_lvt_98beee57fd2ef70ccdd5ca52b9740c49=1573202447,1573367902,1573954769,1573954829; Hm_lpvt_98beee57fd2ef70ccdd5ca52b9740c49=1573955014',
    'Dnt':'1',
    'Referer': 'https://zhuanlan.zhihu.com/p/25198314',
    'Sec-fetch-mode':'navigate',
    'Sec-fetch-site':'none',
    'Sec-fetch-user':'?1',
    'Upgrade-insecure-requests': '1',
    'User-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.97 Safari/537.36'
}

url = "https://www.zhihu.com/people/excited-vczh/activities"
z = requests.get(url,headers=request_headers)
print(z.content)
# Out:
# b'\x01\xfc\xff\x1b\x89\xb0\'\xad\xf6\x1e\x12Q\xd1\xfa!@\x1d\xa9\x0b\x7f\xfe\xfc\xfb#d\x98{\xbe/\x9d\xf5\x9f\x9f\xaf\xda\xda\xe3R\x95\xea\xec\xaaR\xb0w\xc0\x84\xc1\xb3&a\x82\xc3\\d\xf3J\xdd%\xa9\xe2VwOwI>x~\x8f$\x1c\x979\xee8$7\x19\xe6\x00\x93\xdb\x18\x13\xbe\xfe7jI\xfe\xc2\xff\xf0\xf7\x96\xe5N\xa2[\x13\xcf=\xbe\x80\x06\x92\xcd\x1a\x03\xe5\xf2k,\x7f\xb5\\\xd2\xa0"\x03\xd2\x02Q\x96\x8dz{\xa3\xfd\xbf\xd7\xed\xff\xbf~Y~\xbd\xb7\xc4\xb7\x92\x99L&y\xa5\xf9J)\xb7\x85$x\xaa\xdeZ\x02\x82\x06\x08\xcdS\xc4\x08\x82\xe7R<\x8d\xa0\x87\xa3\x01\x82\xfe}0{&|\xf1\xf3\xa6+{\xa7T\xb9\xe9\xdc4g\x9cb\xec\xde{\xff\x173\x82Bb)$\xa0\x90`\x0b\x01[\x8c\xe0\x82\xb4\xec\xff\x7f\xfe\x0c\x92\x08\xa7\xcd,\x97\xd8pi\x9d\x80\r\xb9\x92X\n\xb1\xbb\x85\xe4\xc8\xc5X\xb9h\x80\x0b9\x15\x9dC\x1c\x82C\xc8\x17b\xb7vuE\x7f\xa5\xcb\xc6\xa5]t!>\x86Z\xed\xdd\xee\xf5W\x06\x8e(*\x02b\xda7\x19\xa6\x85\x93\xee\xf7\xdc\xadc\x13\x04\xb2\x18\t\x044U\xadl\xeb\x95}\xbd\xd0O\xcf^\xb5v\x06\xae\xf5\xc6\x96l\xa2g}\x99\xfa\xcc\xcd\xc0P\x0e\xdc
# ...

# %%
headers = {
    'accept': '*/*',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh,en-US;q=0.9,en;q=0.8,zh-TW;q=0.7,zh-CN;q=0.6,zh-HK;q=0.5',
    'content-length': '13',
    'content-type': 'application/json',
    'cookie': '_zap=d756ec26-4319-4aa7-a907-44bef8b8cc4a; _xsrf=2f696c89-c093-47e6-acd0-5284eaa4e181; d_c0="AICjeSCNExCPTifRRV0t2OVtBKiXR9RnNDc=|1568969970"; z_c0="2|1:0|10:1569056218|4:z_c0|92:Mi4xUGJ2eEF3QUFBQUFBZ0tONUlJMFRFQ1lBQUFCZ0FsVk4yak56WGdDVkM2ZUFmNEVac0Y1MGdUc3lINlVhdTBJNnVn|8448475a508b016bc27adcd9b58ea946b641d0e5f6bc2b344b76d298e5f24c73"; q_c1=a690ead776234427b70f3ef6cb9cb5a3|1572073804000|1569056401000; tst=h; tshl=digital; Hm_lvt_98beee57fd2ef70ccdd5ca52b9740c49=1573202447,1573367902,1573954769,1573954829; tgw_l7_route=7f546500f1123d2f6701ac7f30637fd6; Hm_lpvt_98beee57fd2ef70ccdd5ca52b9740c49=1573955932',
    'dnt': '1',
    'origin': 'https://www.zhihu.com',
    'referer': 'https://www.zhihu.com/question/346915031',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.97 Safari/537.36',
    'x-ab-param': 'se_expired_ob=0;se_ctx=0;se_ctr_pyc=0;top_v_album=1;soc_zcfw_broadcast2=1;zr_km_feed_prerank=new;zr_test_aa1=0;top_root=0;ug_zero_follow=0;zr_item_nn_recall=close;zr_km_special=open;zr_video_rank_nn=new_rank;top_quality=0;se_colorfultab=1;se_use_zitem=0;ug_follow_answerer_0=0;zr_infinity_member=close;zr_video_recall=current_recall;soc_stickypush=0;zr_rewrite_query=0;se_cardrank_2=1;se_p_slideshow=1;se_adxtest=1;se_multi_task_new=0;top_ydyq=X;qap_question_author=0;zr_paid_answer_exp=0;tp_sticky_android=2;pf_noti_entry_num=0;se_ltr_dnn_cp=0;se_new_topic=0;se_cardrank_4=1;se_hot_timebox=1;se_movietab=1;li_qa_cover=old;li_tjys_ec_ab=0;ug_follow_answerer=0;se_site_onebox=0;tsp_vote=2;qap_ques_invite=0;zr_slot_cold_start=aver;li_qa_new_cover=1;zr_km_category=open;se_preset_tech=0;soc_bigone=1;se_payconsult=5;top_native_answer=7;soc_update=1;zr_km_feed_nlp=old;zr_paid_answer_mix=mixed_15;se_sug=0;tp_header_style=1;ug_newtag=1;li_se_heat=1;li_qa_btn_text=0;zr_ans_rec=gbrank;tp_topic_head=0;tsp_hotlist_ui=1;soc_notification=1;se_zu_recommend=0;se_dnn_mt=0;tp_club_header=1;tp_sft_v2=d;soc_special=0;ug_goodcomment_0=1;li_pay_banner_type=4;li_ebook_audio=0;se_ad_index=10;se_ltr_user=0;tp_sft=a;top_new_feed=5;soc_bignew=1;zr_expslotpaid=2;se_hotsearch=1;se_zu_onebox=3;se_webrs=1;tp_qa_metacard=1;tp_qa_metacard_top=top;ls_zvideo_like=0;ls_fmp4=0;zr_km_topic_zann=new;zr_recall_heatscore=4_6;se_cardrank_1=0;se_ctr_topic=0;se_famous=1;tp_meta_card=0;tp_m_intro_re_topic=1;li_hot_score_ab=0;zr_km_recall_num=open;se_likebutton=0;soc_leave_recommend=0;se_featured=1;tp_qa_toast=1;top_hotcommerce=3;soc_zcfw_broadcast=0;qap_question_visitor= 0;zr_prerank_heatscore=true;se_whitelist=1;pf_fuceng=1;zr_rel_search=base;se_perf=0;top_universalebook=1;zr_slotpaidexp=8;se_mclick1=0;se_ltr_cp_new=0;se_agency= 0;tp_club_qa_pic=1;sem_up_growth=in_app;zr_new_commodity=0;tp_club_qa=1;li_se_section=1;se_duration=1;se_ctr=0;tsp_billboardhead=2;soc_yxzl_zcfw=0;se_go_ztext=0;se_lottery=0;pf_foltopic_usernum=50;li_vip_no_ad_mon=0;zr_km_style=base;zr_filter=ignore_topics;se_college_cm=1;se_subtext=1;soc_zcfw_shipinshiti=0;ug_zero_follow_0=0;li_se_media_icon=1;zr_km_item_cf=open;se_websearch=3;se_hotmore=0;ug_fw_answ_aut_1=0;ls_zvideo_license=1;li_purchase_test=0;se_ios_spb309=1;se_webtimebox=1;se_ab=0;se_club_post=5;se_college=default;se_backsearch=1;zr_answer_rec_cp=open;zr_km_prerank=new;ls_zvideo_trans=0;se_billboardsearch=1;soc_zcfw_badcase=0;soc_zuichangfangwen=0;zr_km_slot_style=event_card;se_topicfeed=0;se_ctr_user=0;top_ebook=0;li_salt_hot=0;li_video_section=1;zr_km_recall=default;zr_art_rec=base;zr_km_item_prerank=old;se_search_feed=N;se_waterfall=0;se_mobileweb=1;li_paid_answer_exp=0;qap_thanks=0;zw_sameq_sorce=995;se_cardrank_3=0;se_amovietab=1;top_test_4_liguangyi=1;ug_follow_topic_1=2;se_col_boost=1;se_aa_base=0;pf_newguide_vertical=0;se_entity_model_14=1;soc_ri_merge=0;zw_payc_qaedit=0;zr_intervene=0;se_entity_model=1;se_wannasearch=a;li_cln_vl=no;li_album_liutongab=0;se_rel_search=0;pf_creator_card=1;ls_videoad=2;se_webmajorob=0;se_dnn_unbias=1;se_time_threshold=0;zr_article_new=close;zr_book_chap=1;zr_km_answer=open_cvr;se_mclick=0;se_spb309=0;se_multianswer=0;se_topiclabel=1;li_android_vip=0;qap_payc_invite=0;zr_rec_answer_cp=close;zr_video_rank=new_rank;se_auto_syn=0',
    'x-requested-with': 'fetch',
    'x-xsrftoken': '2f696c89-c093-47e6-acd0-5284eaa4e181',
    'x-zse-83': '3_2.0',
    'x-zse-84': 'fTt0b7u0SL2X2MYqmTH0g7uqHh2YnCO8K_xyc6X0g9Yf68S8KTY8k0uqH9xxk_tB'
}

url = "https://www.zhihu.com/api/v4/answers/849384673/voters"
z = requests.get(url,headers)
print(z.content)
# Out:
# b'<html>\r\n<head><title>400 Bad Request</title></head>\r\n<body bgcolor="white">\r\n<center><h1>400 Bad Request</h1></center>\r\n<hr><center>openresty</center>\r\n</body>\r\n</html>\r\n'

# %%
html = u"""
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <title>文章的标题</title>
</head>
<body>
    <div id="app" class="container">
        <h1>h1文字</h1>

        <label for="input">Input</label>
        <textarea id="input" rows="10" class="form-control">
</body>
</html>
"""

# %%
import re

# %%
print(re.findall(pattern='<title>(.*?)</title>', string=html, 
                 flags=re.S)[0])
# Out:
# 文章的标题

# %%
print(re.findall('<hl>(.*?)</hl>',html)[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-7feaa3683c4b> in <module>()
# ----> 1 print(re.findall('<hl>(.*?)</hl>',html)[0])
#
# IndexError: list index out of range

# %%
url = 'https://juejin.im/auth/type/phoneNumber'
r = requests.get(url)
z.status_code
# Out:
# 400

# %%
import random
headers = {
   'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.97 Safari/537.36'
}

# %%
z1 = requests.get(url,headers=headers)
z1.status_code
# Out:
# 404

# %% [markdown]
# 获取_xsrf

# %%
#from lxml import etree
#sel = etree.HTML(z1.content)
#_xsrf = sel.xpath('//input[@name="_xsrf"]/@value')[0]

# %%
loginurl = 'https://www.zhihu.com/login/email'
# 这里的_xsrf就是我们刚刚上面得到的
formdata = {
    'account':'867145391@qq.com',
    'password':'wzq08110811',
    'remenber':'1',
    'url_back':'http://www.zmz2019.com/user/reg'
}
z2 = requests.post(url=loginurl,data=formdata,headers=headers)
print(z2.status_code)
# Out:
# 200

# %%
print (z2.content)
# Out:
# b'<!doctype html>\n<html lang="zh" data-hairline="true" data-theme="light"><head><meta charSet="utf-8"/><title data-react-helmet="true">\xe7\x9f\xa5\xe4\xb9\x8e - \xe6\x9c\x89\xe9\x97\xae\xe9\xa2\x98\xef\xbc\x8c\xe4\xb8\x8a\xe7\x9f\xa5\xe4\xb9\x8e</title><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1"/><meta name="renderer" content="webkit"/><meta name="force-rendering" content="webkit"/><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/><meta name="google-site-verification" content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg"/><meta name="description" property="og:description" content="
# ...

# %%
#print (z2.json()['msg'])

# %% [markdown]
# 由于出现验证码失败
